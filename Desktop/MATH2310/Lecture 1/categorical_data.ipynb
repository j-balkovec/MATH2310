# %%
from matplotlib import pyplot as plt

tree_data = [105, 50, 45]
tree_labels = ["Jeffrey Pine", "Ponderosa", "White Fir"]

plt.pie(tree_data, labels=tree_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x121eabb10>,
# ...
#  [Text(-0.08630492316306847, 1.096609073570804, 'Jeffrey Pine'),
#   Text(-0.6465639108340352, -0.8899185969553607, 'Ponderosa'),
#   Text(0.8364464417647072, -0.7143929941279943, 'White Fir')])

# %%
plt.bar(tree_labels, tree_data)
# Out:
# <BarContainer object of 3 artists>
